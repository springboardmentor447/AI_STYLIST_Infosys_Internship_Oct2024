# %%
import json
data = []
with open("C:/Users/dhara/Downloads/fashion_products_data.ldjson", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line.strip()))
import pandas as pd
df = pd.DataFrame(data)
print(df.head())
# Out:
#                             uniq_id            crawl_timestamp        asin  \
# 0  26d41bdc1495de290bc8e6062d927729  2020-02-07 05:11:36 +0000  B07STS2W9T
# 1  410c62298852e68f34c35560f2311e5a  2020-02-07 08:45:56 +0000  B07N6TD2WL
# 2  52e31bb31680b0ec73de0d781a23cc0a  2020-02-06 11:09:38 +0000  B07WJ6WPN1
# 3  25798d6dc43239c118452d1bee0fb088  2020-02-07 08:32:45 +0000  B07PYSF4WZ
# 4  ad8a5a196d515ef09dfdaf082bdc37c4  2020-02-06 14:27:48 +0000  B082KXNM7X
#
#                                          product_url  \
# 0  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 1  https://www.amazon.in/Sf-Jeans-Pantaloons-T-Sh...
# 2  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 3  https://www.amazon.in/People-Printed-Regular-T...
# 4  https://www.amazon.in/Monte-Carlo-Cotton-Colla...
#
#                                         product_name  \
# 0  LA' Facon Cotton Kalamkari Handblock Saree Blo...
# 1  Sf Jeans By Pantaloons Men's Plain Slim fit T-...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['sales_price'].dropna(), kde=True)  # kde=True adds a density plot
plt.title("Distribution of Sales Price")
plt.xlabel("Sales Price")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['sales_price'].dropna())
plt.title("Box Plot of Sales Price")
plt.xlabel("Sales Price")
plt.show()

# %%
# Scatter Plot between Sales Price and Rating
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sales_price', y='rating', data=df)
plt.title("Scatter Plot of Sales Price vs Rating")
plt.xlabel("Sales Price")
plt.ylabel("Rating")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='amazon_prime__y_or_n', y='sales_price', data=df)
plt.title("Sales Price Distribution by Amazon Prime Status")
plt.xlabel("Amazon Prime (Yes or No)")
plt.ylabel("Sales Price")
plt.show()

# %%
numerical_columns = df.select_dtypes(include=['number']).columns

# Step 2: Compute the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Step 3: Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black')

# Step 4: Display the heatmap
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 8
#       6 # Step 3: Create the heatmap
#       7 plt.figure(figsize=(10, 8))
# ----> 8 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black')
#      10 # Step 4: Display the heatmap
#      11 plt.title("Correlation Heatmap of Numerical Columns")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# ...

# %%
# Step 1: Select only numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns

# Step 2: Check for missing values and handle them (e.g., by filling with 0 or dropping rows/columns)
df = df[numerical_columns].fillna(0)  # Optionally, fill NaN with 0 (or use df.dropna() to drop rows with NaN)

# Step 3: Compute the correlation matrix
correlation_matrix = df.corr()

# Step 4: Check if the correlation matrix is not empty
if correlation_matrix.shape[0] > 0:
    # Create the heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black')

    # Step 5: Display the heatmap
    plt.title("Correlation Heatmap of Numerical Columns")
    plt.show()
else:
    print("The correlation matrix is empty or invalid.")

# %%
# Example of a heatmap showing correlations between numerical columns
plt.figure(figsize=(12, 8))

# Compute the correlation matrix, which shows how columns are correlated
correlation_matrix = df.corr()

# Plot the heatmap with annotations to show correlation values
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Dataset")
plt.show()

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Check if the numeric DataFrame is empty
if not numeric_df.empty:
    correlation_matrix = numeric_df.corr()
    if correlation_matrix.isnull().all().all():
        print("No valid correlations in the dataset to display.")
    else:
        plt.figure(figsize=(12, 8))
        sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
        plt.title("Correlation Heatmap of Dataset")
        plt.show()
else:
    print("No numerical columns available for correlation heatmap.")

# %%
df['sales_price'] = pd.to_numeric(df['sales_price'], errors='coerce')
# Repeat for other columns if necessary
print(df.dtypes)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Color'] = encoder.fit_transform(df['Color'])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df['Color'] = encoder.fit_transform(df['Color'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Color'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(df.columns)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'image_urls__small', 'medium', 'large', 'browsenode', 'brand',
#        'sales_price', 'weight', 'rating', 'sales_rank_in_parent_category',
#        'sales_rank_in_child_category', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'parent___child_category__all',
#        'best_seller_tag__y_or_n', 'other_items_customers_buy',
#        'product_details__k_v_pairs', 'discount_percentage', 'colour',
#        'no__of_reviews', 'seller_name', 'seller_id', 'left_in_stock',
#        'no__of_offers', 'no__of_sellers', 'technical_details__k_v_pairs',
#        'formats___editions', 'name_of_author_for_books'],
#       dtype='object')

# %%
label_encoder = LabelEncoder()

# Encode the 'colour' column
df['colour_encoded'] = label_encoder.fit_transform(df['colour'])

# Check the results
print(df[['colour', 'colour_encoded']].head())
# Out:
#   colour  colour_encoded
# 0    NaN            4757
# 1    NaN            4757
# 2    NaN            4757
# 3    NaN            4757
# 4    NaN            4757

# %%
df['colour_encoded'] = label_encoder.fit_transform(df['colour'])
print(df[['colour', 'colour_encoded']].head())
# Out:
#   colour  colour_encoded
# 0    NaN            4757
# 1    NaN            4757
# 2    NaN            4757
# 3    NaN            4757
# 4    NaN            4757

# %%
# Define the column for which you want to remove outliers
column = 'sales_price'

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df[column].quantile(0.25)
Q3 = df[column].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out rows that contain outliers
df_no_outliers = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 column = 'sales_price'
#       4 # Calculate Q1 (25th percentile) and Q3 (75th percentile)
# ----> 5 Q1 = df[column].quantile(0.25)
#       6 Q3 = df[column].quantile(0.75)
#       7 IQR = Q3 - Q1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:2650, in Series.quantile(self, q, interpolation)
#    2646 # We dispatch to DataFrame so that core.internals only has to worry
#    2647 #  about 2D cases.
#    2648 df = self.to_frame()
# -> 2650 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2651 if result.ndim == 2:
#    2652     result = result.iloc[:, 0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
# ...

# %%
# Convert the column to numeric, coercing non-numeric values to NaN
df['sales_price'] = pd.to_numeric(df['sales_price'], errors='coerce')

# Now check if there are any NaN values and remove them, if needed
df = df.dropna(subset=['sales_price'])

# Now you can proceed with IQR calculation or any other analysis
Q1 = df['sales_price'].quantile(0.25)
Q3 = df['sales_price'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds and filter out outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_no_outliers = df[(df['sales_price'] >= lower_bound) & (df['sales_price'] <= upper_bound)]

# %%
print("First Quartile (Q1):", Q1)
print("Third Quartile (Q3):", Q3)
print("Interquartile Range (IQR):", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)

# Print the filtered DataFrame without outliers
print("Data without outliers:")
print(df_no_outliers)
# Out:
# First Quartile (Q1): 379.0
# Third Quartile (Q3): 899.0
# Interquartile Range (IQR): 520.0
# Lower Bound: -401.0
# Upper Bound: 1679.0
# Data without outliers:
#                                 uniq_id            crawl_timestamp  \
# 0      26d41bdc1495de290bc8e6062d927729  2020-02-07 05:11:36 +0000
# 1      410c62298852e68f34c35560f2311e5a  2020-02-07 08:45:56 +0000
# 2      52e31bb31680b0ec73de0d781a23cc0a  2020-02-06 11:09:38 +0000
# 3      25798d6dc43239c118452d1bee0fb088  2020-02-07 08:32:45 +0000
# 5      73fd23f631d4434fd4a41ecc1b9f5eed  2020-02-06 08:14:03 +0000
# ...                                 ...                        ...
# 29995  976b6bda7076509778da69eb3fe0f59c  2020-02-06 23:53:43 +0000
# 29996  3006a520f71804b055d92216f5dc946d  2020-02-06 20:32:09 +0000
# 29997  45ea7c463997f4cd91851617edbfee32  2020-02-06 19:55:44 +0000
# 29998  2ecada524df6ff8c2d0c53a249cfcddc  2020-02-06 05:08:00 +0000
# 29999  a4e77b9b1addb68bdfc4b178ac27e7c2  2020-02-06 23:32:41 +0000
#
# ...

# %%
# Display all column names in the DataFrame
print(df.columns)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'image_urls__small', 'medium', 'large', 'browsenode', 'brand',
#        'sales_price', 'weight', 'rating', 'sales_rank_in_parent_category',
#        'sales_rank_in_child_category', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'parent___child_category__all',
#        'best_seller_tag__y_or_n', 'other_items_customers_buy',
#        'product_details__k_v_pairs', 'discount_percentage', 'colour',
#        'no__of_reviews', 'seller_name', 'seller_id', 'left_in_stock',
#        'no__of_offers', 'no__of_sellers', 'technical_details__k_v_pairs',
#        'formats___editions', 'name_of_author_for_books'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# uniq_id                              0
# crawl_timestamp                      0
# asin                                 0
# product_url                          0
# product_name                         0
# image_urls__small                    2
# medium                               2
# large                             1159
# browsenode                         520
# brand                             8143
# sales_price                       2890
# weight                               0
# rating                               0
# sales_rank_in_parent_category     4503
# sales_rank_in_child_category      5149
# delivery_type                        0
# meta_keywords                        0
# amazon_prime__y_or_n                 0
# parent___child_category__all      4503
# best_seller_tag__y_or_n              0
# other_items_customers_buy         5637
# product_details__k_v_pairs        1183
# discount_percentage              15376
# colour                           23971
# ...

# %%
df_dropped_rows = df.dropna()

# %%
df_dropped_columns = df.dropna(axis=1)

# %%
print(df_dropped_rows)
# Out:
# Empty DataFrame
# Columns: [uniq_id, crawl_timestamp, asin, product_url, product_name, image_urls__small, medium, large, browsenode, brand, sales_price, weight, rating, sales_rank_in_parent_category, sales_rank_in_child_category, delivery_type, meta_keywords, amazon_prime__y_or_n, parent___child_category__all, best_seller_tag__y_or_n, other_items_customers_buy, product_details__k_v_pairs, discount_percentage, colour, no__of_reviews, seller_name, seller_id, left_in_stock, no__of_offers, no__of_sellers, technical_details__k_v_pairs, formats___editions, name_of_author_for_books]
# Index: []
#
# [0 rows x 33 columns]

# %%
print(df_dropped_rows)
# Out:
# Empty DataFrame
# Columns: [uniq_id, crawl_timestamp, asin, product_url, product_name, image_urls__small, medium, large, browsenode, brand, sales_price, weight, rating, sales_rank_in_parent_category, sales_rank_in_child_category, delivery_type, meta_keywords, amazon_prime__y_or_n, parent___child_category__all, best_seller_tag__y_or_n, other_items_customers_buy, product_details__k_v_pairs, discount_percentage, colour, no__of_reviews, seller_name, seller_id, left_in_stock, no__of_offers, no__of_sellers, technical_details__k_v_pairs, formats___editions, name_of_author_for_books]
# Index: []
#
# [0 rows x 33 columns]

# %%
print(df.columns)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'image_urls__small', 'medium', 'large', 'browsenode', 'brand',
#        'sales_price', 'weight', 'rating', 'sales_rank_in_parent_category',
#        'sales_rank_in_child_category', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'parent___child_category__all',
#        'best_seller_tag__y_or_n', 'other_items_customers_buy',
#        'product_details__k_v_pairs', 'discount_percentage', 'colour',
#        'no__of_reviews', 'seller_name', 'seller_id', 'left_in_stock',
#        'no__of_offers', 'no__of_sellers', 'technical_details__k_v_pairs',
#        'formats___editions', 'name_of_author_for_books'],
#       dtype='object')

# %%
print(df.rows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16784\1815158371.py in ?()
# ----> 1 print(df.rows)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
print(df.head())

# View the first 10 rows
print(df.head(10))

# View the last 5 rows
print(df.tail())
# Out:
#                             uniq_id            crawl_timestamp        asin  \
# 0  26d41bdc1495de290bc8e6062d927729  2020-02-07 05:11:36 +0000  B07STS2W9T
# 1  410c62298852e68f34c35560f2311e5a  2020-02-07 08:45:56 +0000  B07N6TD2WL
# 2  52e31bb31680b0ec73de0d781a23cc0a  2020-02-06 11:09:38 +0000  B07WJ6WPN1
# 3  25798d6dc43239c118452d1bee0fb088  2020-02-07 08:32:45 +0000  B07PYSF4WZ
# 4  ad8a5a196d515ef09dfdaf082bdc37c4  2020-02-06 14:27:48 +0000  B082KXNM7X
#
#                                          product_url  \
# 0  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 1  https://www.amazon.in/Sf-Jeans-Pantaloons-T-Sh...
# 2  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 3  https://www.amazon.in/People-Printed-Regular-T...
# 4  https://www.amazon.in/Monte-Carlo-Cotton-Colla...
#
#                                         product_name  \
# 0  LA' Facon Cotton Kalamkari Handblock Saree Blo...
# 1  Sf Jeans By Pantaloons Men's Plain Slim fit T-...
# ...

# %%
# Display all values in the 'name_of_author_for_books' column
print(df['name_of_author_for_books'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 29995    NaN
# 29996    NaN
# 29997    NaN
# 29998    NaN
# 29999    NaN
# Name: name_of_author_for_books, Length: 30000, dtype: object

# %%
# Set the threshold for minimum number of non-NA values (50% of total rows here)
threshold = df.shape[0] * 0.5  # Adjust 0.5 to any percentage you prefer

# Drop columns that have less than 50% non-NA values
df_cleaned = df.dropna(axis=1, thresh=threshold)

# Display the cleaned DataFrame
print(df_cleaned.columns)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'image_urls__small', 'medium', 'large', 'browsenode', 'brand',
#        'sales_price', 'weight', 'rating', 'sales_rank_in_parent_category',
#        'sales_rank_in_child_category', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'parent___child_category__all',
#        'best_seller_tag__y_or_n', 'other_items_customers_buy',
#        'product_details__k_v_pairs'],
#       dtype='object')

# %%
df_cleaned = df.dropna(axis=1)
print(df_cleaned.columns)
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'weight', 'rating', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'best_seller_tag__y_or_n'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[['column_name']] = scaler.fit_transform(df[['column_name']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sklearn.preprocessing import MinMaxScaler
#       3 scaler = MinMaxScaler()
# ----> 4 df[['column_name']] = scaler.fit_transform(df[['column_name']])
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[['column_name']] = scaler.fit_transform(df[['column_name']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 from sklearn.preprocessing import MinMaxScaler
#       3 scaler = MinMaxScaler()
# ----> 4 df[['column_name']] = scaler.fit_transform(df[['column_name']])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df['sales_price'].fillna(df['sales_price'].median(), inplace=True)

# %%
threshold = len(df) * 0.5
df = df.dropna(thresh=threshold, axis=1)

# %%
print(df.head())
# Out:
#                             uniq_id            crawl_timestamp        asin  \
# 0  26d41bdc1495de290bc8e6062d927729  2020-02-07 05:11:36 +0000  B07STS2W9T
# 1  410c62298852e68f34c35560f2311e5a  2020-02-07 08:45:56 +0000  B07N6TD2WL
# 2  52e31bb31680b0ec73de0d781a23cc0a  2020-02-06 11:09:38 +0000  B07WJ6WPN1
# 3  25798d6dc43239c118452d1bee0fb088  2020-02-07 08:32:45 +0000  B07PYSF4WZ
# 4  ad8a5a196d515ef09dfdaf082bdc37c4  2020-02-06 14:27:48 +0000  B082KXNM7X
#
#                                          product_url  \
# 0  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 1  https://www.amazon.in/Sf-Jeans-Pantaloons-T-Sh...
# 2  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 3  https://www.amazon.in/People-Printed-Regular-T...
# 4  https://www.amazon.in/Monte-Carlo-Cotton-Colla...
#
#                                         product_name  \
# 0  LA' Facon Cotton Kalamkari Handblock Saree Blo...
# 1  Sf Jeans By Pantaloons Men's Plain Slim fit T-...
# ...

# %%
print(df['name_of_author_for_books'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name_of_author_for_books'
#
# ...

# %%
import pandas as pd

columns_to_display = ['asin', 'product_url', 'product_name', 'sales_price', 'rating', 'meta_keywords', 'medium', 'brand']


filtered_df = df[columns_to_display]


print(filtered_df)
# Out:
#              asin                                        product_url  \
# 0      B07STS2W9T  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 1      B07N6TD2WL  https://www.amazon.in/Sf-Jeans-Pantaloons-T-Sh...
# 2      B07WJ6WPN1  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 3      B07PYSF4WZ  https://www.amazon.in/People-Printed-Regular-T...
# 4      B082KXNM7X  https://www.amazon.in/Monte-Carlo-Cotton-Colla...
# ...           ...                                                ...
# 29995  B07FVRMFTX  https://www.amazon.in/Indian-Virasat-Pushp-Cha...
# 29996  B07RR3XYZD  https://www.amazon.in/Urban-Ranger-Pantaloons-...
# 29997  B07SSLSR9X  https://www.amazon.in/Peter-England-Striped-Re...
# 29998  B07P561W67  https://www.amazon.in/PINKY-PARI-Womens-Embroi...
# 29999  B07GPQ7V5W  https://www.amazon.in/Gutsy-Triple-Striped-Sle...
#
#                                             product_name sales_price rating  \
# ...

# %%
# Remove rows with null values in the specified columns
filtered_df = filtered_df.dropna(subset=columns_to_display)

# Print the DataFrame after removing rows with null values
print(filtered_df)
# Out:
#              asin                                        product_url  \
# 0      B07STS2W9T  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 2      B07WJ6WPN1  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 5      B07X5M41BJ  https://www.amazon.in/Forest-Club-Sports-Breat...
# 6      B07H9RCVHQ  https://www.amazon.in/Graphic-Printed-T-Shirt-...
# 9      B07P43X53C  https://www.amazon.in/Peppermint-Synthetic-lin...
# ...           ...                                                ...
# 29989  B07Z5GSFMP  https://www.amazon.in/Disney-Zilingo-Frozen-Pr...
# 29991  B081ZL32TW  https://www.amazon.in/INKOVY-Cotton-Printed-Ts...
# 29996  B07RR3XYZD  https://www.amazon.in/Urban-Ranger-Pantaloons-...
# 29998  B07P561W67  https://www.amazon.in/PINKY-PARI-Womens-Embroi...
# 29999  B07GPQ7V5W  https://www.amazon.in/Gutsy-Triple-Striped-Sle...
#
#                                             product_name sales_price rating  \
# ...

# %%
import re

# Remove special characters from the 'product_name' column
filtered_df['product_name'] = filtered_df['product_name'].str.replace(r'[?|!|\\|#|\.|"|\(|\)|/|,|:|\'|-|\$|\+|~|;|_|@|>|<]', '', regex=True)

# Print the DataFrame to see the cleaned 'product_name' column
print(filtered_df[['product_name']])
# Out:
#                                             product_name
# 0      LA Facon Cotton Kalamkari Handblock Saree Blou...
# 2      LOVISTA Cotton Gota Patti Tassel Traditional P...
# 5      Forest Club  Gym Wear  Sports Shorts Shorts fo...
# 6      PrintOctopus Graphic Printed T-Shirt for Men C...
# 9                             Peppermint Synthetic Dress
# ...                                                  ...
# 29989  Disney X Zilingo Girls Frozen Printed Sleevele...
# 29991              INKOVY Mens Solid Regular Fit T-Shirt
# 29996   Urban Ranger by Pantaloons Mens Slim fit T-Shirt
# 29998  PINKY PARI Womens Embroidered Short Denim Stra...
# 29999  Gutsy Mens Full Sleeve All Over Printed Navy T...
#
# [19233 rows x 1 columns]

# %%
# Print only the 'product_name' column before cleaning
print(df['product_name'])
# Out:
# 0        LA' Facon Cotton Kalamkari Handblock Saree Blo...
# 1        Sf Jeans By Pantaloons Men's Plain Slim fit T-...
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                 People Men's Printed Regular fit T-Shirt
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995          Indian Virasat Women's Rayon Anarkali Kurta
# 29996    Urban Ranger by Pantaloons Men's Slim fit T-Shirt
# 29997              Peter England Men's Regular fit T-Shirt
# 29998    PINKY PARI Women's Embroidered Short Denim Str...
# 29999    Gutsy Men's Full Sleeve All Over Printed Navy ...
# Name: product_name, Length: 30000, dtype: object

# %%
# Display the first 1000 rows of the cleaned DataFrame
print(filtered_df.head(1000))
# Out:
#             asin                                        product_url  \
# 0     B07STS2W9T  https://www.amazon.in/Facon-Kalamkari-Handbloc...
# 2     B07WJ6WPN1  https://www.amazon.in/LOVISTA-Traditional-Prin...
# 5     B07X5M41BJ  https://www.amazon.in/Forest-Club-Sports-Breat...
# 6     B07H9RCVHQ  https://www.amazon.in/Graphic-Printed-T-Shirt-...
# 9     B07P43X53C  https://www.amazon.in/Peppermint-Synthetic-lin...
# ...          ...                                                ...
# 1534  B07R79GVSQ  https://www.amazon.in/Crazy-Prints-Cotton-Indi...
# 1536  B0811QQ1J4  https://www.amazon.in/MALLORY-WINSTON-Honeymoo...
# 1538  B07P55BLR7  https://www.amazon.in/Fourfolds-Piece-Blazer-W...
# 1541  B07PJDJHPZ  https://www.amazon.in/uniq-chennai-Super-Jerse...
# 1542  B079TLJMH1  https://www.amazon.in/PerfectBlue-Cotton-Saree...
#
#                                            product_name sales_price rating  \
# ...

# %%
print(filtered_df['product_name'].head(1000))
# Out:
# 0       LA Facon Cotton Kalamkari Handblock Saree Blou...
# 2       LOVISTA Cotton Gota Patti Tassel Traditional P...
# 5       Forest Club  Gym Wear  Sports Shorts Shorts fo...
# 6       PrintOctopus Graphic Printed T-Shirt for Men C...
# 9                              Peppermint Synthetic Dress
#                               ...
# 1534    Crazy Prints Mens Cotton Indian Cricket Cap Ro...
# 1536    MALLORY WINSTON Womens Babydoll Nighty for Hon...
# 1538    Fourfolds 5 Piece Coat Suit with Shirt Pant Bl...
# 1541                    uniq chennai Super Kings Jersey …
# 1542    Perfectblue Women`s Cotton Silk saree With Blo...
# Name: product_name, Length: 1000, dtype: object

# %%
print(filtered_df['product_name'].head(10))
# Out:
# 0     LA Facon Cotton Kalamkari Handblock Saree Blou...
# 2     LOVISTA Cotton Gota Patti Tassel Traditional P...
# 5     Forest Club  Gym Wear  Sports Shorts Shorts fo...
# 6     PrintOctopus Graphic Printed T-Shirt for Men C...
# 9                            Peppermint Synthetic Dress
# 12    Jevi Prints Womens Cotton Printed Straight Kur...
# 13    OLLI Mens Orange Lex Purple White Cotton Brief...
# 15    Miss Chase Womens Solid Shoulder Cut-Out Half-...
# 16                 bebe Women Genuine Leather Slim Belt
# 17                       Colt by Unlimited Mens T-Shirt
# Name: product_name, dtype: object

# %%
import nltk
from nltk.corpus import stopwords

# Download the stopwords from nltk (only needs to be run once)
nltk.download('stopwords')

# Get the list of stopwords in English
stop_words = set(stopwords.words('english'))

# Remove stopwords from the 'product_name' column
filtered_df['product_name'] = filtered_df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words])
)

# Print the cleaned 'product_name' column to verify
print(filtered_df['product_name'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import nltk
#       2 from nltk.corpus import stopwords
#       4 # Download the stopwords from nltk (only needs to be run once)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
pip install nltk
# Out:
#   Cell In[17], line 1
#     pip install nltk
#         ^
# SyntaxError: invalid syntax

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.corpus import stopwords

# Download the stopwords from nltk (only needs to be run once)
nltk.download('stopwords')

# Get the list of stopwords in English
stop_words = set(stopwords.words('english'))

# Remove stopwords from the 'product_name' column
filtered_df['product_name'] = filtered_df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words])
)

# Print the cleaned 'product_name' column to verify
print(filtered_df['product_name'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# 0        LA Facon Cotton Kalamkari Handblock Saree Blou...
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 5        Forest Club Gym Wear Sports Shorts Shorts Men ...
# 6        PrintOctopus Graphic Printed T-Shirt Men Chill...
# 9                               Peppermint Synthetic Dress
#                                ...
# 29989    Disney X Zilingo Girls Frozen Printed Sleevele...
# 29991                INKOVY Mens Solid Regular Fit T-Shirt
# 29996        Urban Ranger Pantaloons Mens Slim fit T-Shirt
# 29998    PINKY PARI Womens Embroidered Short Denim Stra...
# 29999          Gutsy Mens Full Sleeve Printed Navy T-Shirt
# Name: product_name, Length: 19233, dtype: object

# %%
print(df['product_name'])
# Out:
# 0        LA' Facon Cotton Kalamkari Handblock Saree Blo...
# 1        Sf Jeans By Pantaloons Men's Plain Slim fit T-...
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                 People Men's Printed Regular fit T-Shirt
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995          Indian Virasat Women's Rayon Anarkali Kurta
# 29996    Urban Ranger by Pantaloons Men's Slim fit T-Shirt
# 29997              Peter England Men's Regular fit T-Shirt
# 29998    PINKY PARI Women's Embroidered Short Denim Str...
# 29999    Gutsy Men's Full Sleeve All Over Printed Navy ...
# Name: product_name, Length: 30000, dtype: object

# %%
import re

# Remove words that contain any non-English letters
filtered_df['product_name'] = df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if re.match("^[A-Za-z]+$", word)])
)

# Print the cleaned 'product_name' column to verify
print(filtered_df['product_name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import re
#       3 # Remove words that contain any non-English letters
# ----> 4 filtered_df['product_name'] = df['product_name'].apply(
#       5     lambda x: ' '.join([word for word in x.split() if re.match("^[A-Za-z]+$", word)])
#       6 )
#       8 # Print the cleaned 'product_name' column to verify
#       9 print(filtered_df['product_name'])
#
# NameError: name 'filtered_df' is not defined

# %%
import re

# Ensure you are using the correct DataFrame name
df['product_name'] = df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if re.match("^[A-Za-z]+$", word)])
)

# Print the cleaned 'product_name' column to verify
print(df['product_name'])
# Out:
# 0        Facon Cotton Kalamkari Handblock Saree Blouse ...
# 1                    Sf Jeans By Pantaloons Plain Slim fit
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                               People Printed Regular fit
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995                  Indian Virasat Rayon Anarkali Kurta
# 29996                  Urban Ranger by Pantaloons Slim fit
# 29997                            Peter England Regular fit
# 29998    PINKY PARI Embroidered Short Denim Straight fi...
# 29999              Gutsy Full Sleeve All Over Printed Navy
# Name: product_name, Length: 30000, dtype: object

# %%
import re

# Ensure you are using the correct DataFrame name
df['product_name'] = df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if re.match("^[A-Za-z]+$", word)])
)

# Print the cleaned 'product_name' column to verify
print(df['product_name'])
# Out:
# 0        Facon Cotton Kalamkari Handblock Saree Blouse ...
# 1                    Sf Jeans By Pantaloons Plain Slim fit
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                               People Printed Regular fit
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995                  Indian Virasat Rayon Anarkali Kurta
# 29996                  Urban Ranger by Pantaloons Slim fit
# 29997                            Peter England Regular fit
# 29998    PINKY PARI Embroidered Short Denim Straight fi...
# 29999              Gutsy Full Sleeve All Over Printed Navy
# Name: product_name, Length: 30000, dtype: object

# %%
import re

# Keep words that contain only English letters and numbers
df['product_name'] = df['product_name'].apply(
    lambda x: ' '.join([word for word in x.split() if re.match("^[A-Za-z0-9]+$", word)])
)

# Print the cleaned 'product_name' column to verify
print(df['product_name'])
# Out:
# 0        Facon Cotton Kalamkari Handblock Saree Blouse ...
# 1                    Sf Jeans By Pantaloons Plain Slim fit
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                               People Printed Regular fit
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995                  Indian Virasat Rayon Anarkali Kurta
# 29996                  Urban Ranger by Pantaloons Slim fit
# 29997                            Peter England Regular fit
# 29998    PINKY PARI Embroidered Short Denim Straight fi...
# 29999              Gutsy Full Sleeve All Over Printed Navy
# Name: product_name, Length: 30000, dtype: object

# %%
import re

# Define a dictionary of common contractions and their expanded forms
contractions = {
    "I'm": "I am",
    "I've": "I have",
    "I'll": "I will",
    "I'd": "I would",
    "you're": "you are",
    "you've": "you have",
    "you'll": "you will",
    "you'd": "you would",
    "he's": "he is",
    "he'll": "he will",
    "he'd": "he would",
    "she's": "she is",
    "she'll": "she will",
    "she'd": "she would",
    "it's": "it is",
    "it'll": "it will",
    "we're": "we are",
    "we've": "we have",
    "we'll": "we will",
    "we'd": "we would",
    "they're": "they are",
    "they've": "they have",
    "they'll": "they will",
    "they'd": "they would",
    "that's": "that is",
    "there's": "there is",
    "here's": "here is",
    "who's": "who is",
    "what's": "what is",
    "where's": "where is",
    "when's": "when is",
    "why's": "why is",
    "how's": "how is",
    "can't": "cannot",
    "won't": "will not",
    "n't": " not",  # for cases like "isn't" -> "is not"
    "'re": " are",  # for cases like "they're" -> "they are"
    "'ve": " have", # for cases like "we've" -> "we have"
    "'ll": " will", # for cases like "she'll" -> "she will"
    "'d": " would", # for cases like "I'd" -> "I would"
    "'s": " is"     # for cases like "it's" -> "it is"
}

# Function to replace contractions in a text
def expand_contractions(text):
    for contraction, expanded in contractions.items():
        text = re.sub(r'\b' + re.escape(contraction) + r'\b', expanded, text)
    return text

# Apply the function to the 'product_name' column
df['product_name'] = df['product_name'].apply(expand_contractions)

# Print the cleaned 'product_name' column to verify
print(df['product_name'])
# Out:
# 0        Facon Cotton Kalamkari Handblock Saree Blouse ...
# 1                    Sf Jeans By Pantaloons Plain Slim fit
# 2        LOVISTA Cotton Gota Patti Tassel Traditional P...
# 3                               People Printed Regular fit
# 4        Monte Carlo Grey Solid Cotton Blend Polo Colla...
#                                ...
# 29995                  Indian Virasat Rayon Anarkali Kurta
# 29996                  Urban Ranger by Pantaloons Slim fit
# 29997                            Peter England Regular fit
# 29998    PINKY PARI Embroidered Short Denim Straight fi...
# 29999              Gutsy Full Sleeve All Over Printed Navy
# Name: product_name, Length: 30000, dtype: object

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet

# Download the required NLTK resources (only needs to be done once)
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
# Initialize the PorterStemmer
stemmer = PorterStemmer()

# Sample text
text = ["running", "runner", "ran", "happiness", "happily"]

# Apply stemming
stemmed_words = [stemmer.stem(word) for word in text]
print("Stemming Result:", stemmed_words)
# Out:
# Stemming Result: ['run', 'runner', 'ran', 'happi', 'happili']

# %%
def stem_and_lemmatize(words):
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()

    # Stemming
    stemmed = [stemmer.stem(word) for word in words]
    print("Stemmed Words:", stemmed)

    # Lemmatization with POS tagging
    lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words]
    print("Lemmatized Words:", lemmatized)

# Sample text
words = ["running", "runner", "ran", "happiness", "happily"]
stem_and_lemmatize(words)
# Out:
# Stemmed Words: ['run', 'runner', 'ran', 'happi', 'happili']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 15
#      13 # Sample text
#      14 words = ["running", "runner", "ran", "happiness", "happily"]
# ---> 15 stem_and_lemmatize(words)
#
# Cell In[13], line 10, in stem_and_lemmatize(words)
#       7 print("Stemmed Words:", stemmed)
#       9 # Lemmatization with POS tagging
# ---> 10 lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words]
#      11 print("Lemmatized Words:", lemmatized)
#
# Cell In[13], line 10, in <listcomp>(.0)
#       7 print("Stemmed Words:", stemmed)
#       9 # Lemmatization with POS tagging
# ---> 10 lemmatized = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words]
#      11 print("Lemmatized Words:", lemmatized)
#
# NameError: name 'get_wordnet_pos' is not defined

# %%
# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Function to get POS tag
def get_wordnet_pos(word):
    # Map POS tag from NLTK to WordNet POS
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
print("Lemmatization Result:", lemmatized_words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[14], line 12
#       9     return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found
#      11 # Apply lemmatization
# ---> 12 lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
#      13 print("Lemmatization Result:", lemmatized_words)
#
# Cell In[14], line 12, in <listcomp>(.0)
#       9     return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found
#      11 # Apply lemmatization
# ---> 12 lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
#      13 print("Lemmatization Result:", lemmatized_words)
#
# Cell In[14], line 7, in get_wordnet_pos(word)
#       5 def get_wordnet_pos(word):
#       6     # Map POS tag from NLTK to WordNet POS
# ----> 7     tag = nltk.pos_tag([word])[0][1][0].upper()
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
lemmatizer = WordNetLemmatizer()

# Function to get POS tag
def get_wordnet_pos(word):
    # Map POS tag from NLTK to WordNet POS
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
print("Lemmatization Result:", lemmatized_words)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[16], line 11
#       8     return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found
#      10 # Apply lemmatization
# ---> 11 lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
#      12 print("Lemmatization Result:", lemmatized_words)
#
# Cell In[16], line 11, in <listcomp>(.0)
#       8     return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found
#      10 # Apply lemmatization
# ---> 11 lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
#      12 print("Lemmatization Result:", lemmatized_words)
#
# Cell In[16], line 6, in get_wordnet_pos(word)
#       4 def get_wordnet_pos(word):
#       5     # Map POS tag from NLTK to WordNet POS
# ----> 6     tag = nltk.pos_tag([word])[0][1][0].upper()
# ...

# %%
import nltk

# Download necessary resources
nltk.download('averaged_perceptron_tagger')  # For POS tagging
nltk.download('punkt')  # For tokenization
nltk.download('wordnet')  # For WordNet lemmatizer
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# Download WordNet data (only needs to be done once)
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

lemmatizer = WordNetLemmatizer()

# Define a function to get the POS tag in WordNet format
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if POS tag isn't found

# Sample text
text = ["rocks", "running", "better", "ate"]

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
print("Lemmatized Words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[18], line 22
#      19 text = ["rocks", "running", "better", "ate"]
#      21 # Apply lemmatization
# ---> 22 lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
#      23 print("Lemmatized Words:", lemmatized_words)
#
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# Download WordNet data (only needs to be done once)
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')

lemmatizer = WordNetLemmatizer()

# Define a function to get the POS tag in WordNet format
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if POS tag isn't found

# Sample text
text = ["rocks", "running", "better", "ate"]

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]
print("Lemmatized Words:", lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dhara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Lemmatized Words: ['rock', 'run', 'well', 'ate']

# %%
lemmatizer = WordNetLemmatizer()

# Function to map POS tag to WordNet POS tag
def get_wordnet_pos(word):
    # Get POS tag for the word
    tag = nltk.pos_tag([word])[0][1][0].upper()  # POS tag
    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}
    return tag_dict.get(tag, wordnet.NOUN)  # Default to noun if tag not found

# Text for lemmatization
text = ["ate", "better", "cats"]

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in text]

# Show the lemmatization results
print("Lemmatization Result:", lemmatized_words)
# Out:
# Lemmatization Result: ['ate', 'well', 'cat']
